# %% [markdown]
# ### Data wrangling without loss
#
# Inspect the “patients_lab_results_messy.csv” dataset
#
# What is wrong with the dataset? Look for e.g.
# - Inconsistent labelling
# - Inconsistent casing
# - Missing values
#
# Fix the issues without loosing any data!
#
# Discuss the reversibility of your steps and think about how you can make sure that you did not loose any data!

# %%
import pandas as pd

df = pd.read_csv("patients_results_messy.csv")
df
# Out:
#   Patient_ID  Visit Date   age  Gender Blood Pressure (mmHg)  Chol (mg_dl)  \
# 0       P001  2021-01-03  34.0    Male                120/80         180.0
# 1       P002   2021/1/05  45.0  FEMALE                135/90         210.0
# 2       P003  03-01-2021  29.0    male                115/75         190.0
# 3       p004  2021.01.04  52.0       F                140/95         220.0
# 4       P005  2021-01-06  33.0       M                118/78         185.0
# 5       P006  2021-01-06  33.0       M                118/78         185.0
# 6       P007  2021/01/07   NaN    Male                125/82         200.0
# 7       P008  2021-01-08  46.0  Female                130/85         195.0
# 8       P009  2021-01-09  50.0  female                128/84           NaN
# 9       P010  2021-01-10  41.0    MALE                132/88         210.0
#
#    glucose            Notes
# 0       95         baseline
# 1      NaN                -
# 2       88          recheck
# 3  missing      new patient
# 4       89           repeat
# 5       89           repeat
# 6   ninety  typo in glucose
# 7      100         baseline
# 8       92                -
# 9       97        follow-up

# %% [markdown]
# Clean up column names using string methods:

# %%
df.columns = df.columns.str.lower().str.replace('[^a-z0-9]+', '_', regex=True).str.strip('_')
df
# Out:
#   patient_id  visit_date   age  gender blood_pressure_mmhg  chol_mg_dl  \
# 0       P001  2021-01-03  34.0    Male              120/80       180.0
# 1       P002   2021/1/05  45.0  FEMALE              135/90       210.0
# 2       P003  03-01-2021  29.0    male              115/75       190.0
# 3       p004  2021.01.04  52.0       F              140/95       220.0
# 4       P005  2021-01-06  33.0       M              118/78       185.0
# 5       P006  2021-01-06  33.0       M              118/78       185.0
# 6       P007  2021/01/07   NaN    Male              125/82       200.0
# 7       P008  2021-01-08  46.0  Female              130/85       195.0
# 8       P009  2021-01-09  50.0  female              128/84         NaN
# 9       P010  2021-01-10  41.0    MALE              132/88       210.0
#
#    glucose            notes
# 0       95         baseline
# 1      NaN                -
# 2       88          recheck
# 3  missing      new patient
# 4       89           repeat
# 5       89           repeat
# 6   ninety  typo in glucose
# 7      100         baseline
# 8       92                -
# 9       97        follow-up

# %%
df.patient_id
# Out:
# 0    P001
# 1    P002
# 2    P003
# 3    p004
# 4    P005
# 5    P006
# 6    P007
# 7    P008
# 8    P009
# 9    P010
# Name: patient_id, dtype: object

# %% [markdown]
# Split blood pressure values into two columns, using the string method split():

# %%
df[['systolic', 'diastolic']] = df['blood_pressure_mmhg'].str.split('/', expand=True)
df
# Out:
#   patient_id  visit_date   age  gender blood_pressure_mmhg  chol_mg_dl  \
# 0       P001  2021-01-03  34.0    Male              120/80       180.0
# 1       P002   2021/1/05  45.0  FEMALE              135/90       210.0
# 2       P003  03-01-2021  29.0    male              115/75       190.0
# 3       p004  2021.01.04  52.0       F              140/95       220.0
# 4       P005  2021-01-06  33.0       M              118/78       185.0
# 5       P006  2021-01-06  33.0       M              118/78       185.0
# 6       P007  2021/01/07   NaN    Male              125/82       200.0
# 7       P008  2021-01-08  46.0  Female              130/85       195.0
# 8       P009  2021-01-09  50.0  female              128/84         NaN
# 9       P010  2021-01-10  41.0    MALE              132/88       210.0
#
#    glucose            notes systolic diastolic
# 0       95         baseline      120        80
# 1      NaN                -      135        90
# 2       88          recheck      115        75
# 3  missing      new patient      140        95
# 4       89           repeat      118        78
# 5       89           repeat      118        78
# 6   ninety  typo in glucose      125        82
# 7      100         baseline      130        85
# 8       92                -      128        84
# 9       97        follow-up      132        88

# %%
df.systolic=df.systolic.apply(pd.to_numeric)
df.diastolic=df.diastolic.apply(pd.to_numeric)
df
# Out:
#   patient_id  visit_date   age  gender blood_pressure_mmhg  chol_mg_dl  \
# 0       P001  2021-01-03  34.0    Male              120/80       180.0
# 1       P002   2021/1/05  45.0  FEMALE              135/90       210.0
# 2       P003  03-01-2021  29.0    male              115/75       190.0
# 3       p004  2021.01.04  52.0       F              140/95       220.0
# 4       P005  2021-01-06  33.0       M              118/78       185.0
# 5       P006  2021-01-06  33.0       M              118/78       185.0
# 6       P007  2021/01/07   NaN    Male              125/82       200.0
# 7       P008  2021-01-08  46.0  Female              130/85       195.0
# 8       P009  2021-01-09  50.0  female              128/84         NaN
# 9       P010  2021-01-10  41.0    MALE              132/88       210.0
#
#    glucose            notes  systolic  diastolic
# 0       95         baseline       120         80
# 1      NaN                -       135         90
# 2       88          recheck       115         75
# 3  missing      new patient       140         95
# 4       89           repeat       118         78
# 5       89           repeat       118         78
# 6   ninety  typo in glucose       125         82
# 7      100         baseline       130         85
# 8       92                -       128         84
# 9       97        follow-up       132         88

# %%
df.systolic
# Out:
# 0    120
# 1    135
# 2    115
# 3    140
# 4    118
# 5    118
# 6    125
# 7    130
# 8    128
# 9    132
# Name: systolic, dtype: int64

# %% [markdown]
# Convert glucose values:

# %%
df['glucose_clean'] = pd.to_numeric(df['glucose'], errors="coerce") # avoids crashing if wrong types are parsed
df
# Out:
#   patient_id  visit_date   age  gender blood_pressure_mmhg  chol_mg_dl  \
# 0       P001  2021-01-03  34.0    Male              120/80       180.0
# 1       P002   2021/1/05  45.0  FEMALE              135/90       210.0
# 2       P003  03-01-2021  29.0    male              115/75       190.0
# 3       p004  2021.01.04  52.0       F              140/95       220.0
# 4       P005  2021-01-06  33.0       M              118/78       185.0
# 5       P006  2021-01-06  33.0       M              118/78       185.0
# 6       P007  2021/01/07   NaN    Male              125/82       200.0
# 7       P008  2021-01-08  46.0  Female              130/85       195.0
# 8       P009  2021-01-09  50.0  female              128/84         NaN
# 9       P010  2021-01-10  41.0    MALE              132/88       210.0
#
#    glucose            notes  systolic  diastolic  glucose_clean
# 0       95         baseline       120         80           95.0
# 1      NaN                -       135         90            NaN
# 2       88          recheck       115         75           88.0
# 3  missing      new patient       140         95            NaN
# 4       89           repeat       118         78           89.0
# 5       89           repeat       118         78           89.0
# 6   ninety  typo in glucose       125         82            NaN
# 7      100         baseline       130         85          100.0
# 8       92                -       128         84           92.0
# 9       97        follow-up       132         88           97.0

# %% [markdown]
# Standardize gender:

# %%
df['gender'] = df['gender'].str.upper().map({'MALE': 'M', 'FEMALE': 'F', 'M': 'M', 'F': 'F'})
df
# Out:
#   patient_id  visit_date   age gender blood_pressure_mmhg  chol_mg_dl  \
# 0       P001  2021-01-03  34.0      M              120/80       180.0
# 1       P002   2021/1/05  45.0      F              135/90       210.0
# 2       P003  03-01-2021  29.0      M              115/75       190.0
# 3       p004  2021.01.04  52.0      F              140/95       220.0
# 4       P005  2021-01-06  33.0      M              118/78       185.0
# 5       P006  2021-01-06  33.0      M              118/78       185.0
# 6       P007  2021/01/07   NaN      M              125/82       200.0
# 7       P008  2021-01-08  46.0      F              130/85       195.0
# 8       P009  2021-01-09  50.0      F              128/84         NaN
# 9       P010  2021-01-10  41.0      M              132/88       210.0
#
#    glucose            notes  systolic  diastolic  glucose_clean
# 0       95         baseline       120         80           95.0
# 1      NaN                -       135         90            NaN
# 2       88          recheck       115         75           88.0
# 3  missing      new patient       140         95            NaN
# 4       89           repeat       118         78           89.0
# 5       89           repeat       118         78           89.0
# 6   ninety  typo in glucose       125         82            NaN
# 7      100         baseline       130         85          100.0
# 8       92                -       128         84           92.0
# 9       97        follow-up       132         88           97.0

# %% [markdown]
# Parse dates to standard format:

# %%
# standardize visit_date
df['visit_date'] = (
    df['visit_date']
    .str.replace(r'[./]', '-', regex=True)  # unify separators
    .str.strip()
)

df['visit_date_clean'] = pd.to_datetime(df['visit_date'], errors='coerce')
df
# Out:
#   patient_id  visit_date   age gender blood_pressure_mmhg  chol_mg_dl  \
# 0       P001  2021-01-03  34.0      M              120/80       180.0
# 1       P002   2021-1-05  45.0      F              135/90       210.0
# 2       P003  03-01-2021  29.0      M              115/75       190.0
# 3       p004  2021-01-04  52.0      F              140/95       220.0
# 4       P005  2021-01-06  33.0      M              118/78       185.0
# 5       P006  2021-01-06  33.0      M              118/78       185.0
# 6       P007  2021-01-07   NaN      M              125/82       200.0
# 7       P008  2021-01-08  46.0      F              130/85       195.0
# 8       P009  2021-01-09  50.0      F              128/84         NaN
# 9       P010  2021-01-10  41.0      M              132/88       210.0
#
#    glucose            notes  systolic  diastolic  glucose_clean  \
# 0       95         baseline       120         80           95.0
# 1      NaN                -       135         90            NaN
# 2       88          recheck       115         75           88.0
# 3  missing      new patient       140         95            NaN
# 4       89           repeat       118         78           89.0
# 5       89           repeat       118         78           89.0
# 6   ninety  typo in glucose       125         82            NaN
# 7      100         baseline       130         85          100.0
# 8       92                -       128         84           92.0
# 9       97        follow-up       132         88           97.0
#
#   visit_date_clean
# 0       2021-01-03
# 1       2021-01-05
# 2              NaT
# 3       2021-01-04
# 4       2021-01-06
# 5       2021-01-06
# 6       2021-01-07
# 7       2021-01-08
# 8       2021-01-09
# 9       2021-01-10

# %% [markdown]
# Fill or flag missing data (no deletions) in some of the columns:

# %% [markdown]
# Further cleanup: patient_id!

# %%
df.patient_id=df.patient_id.str.upper()
df
# Out:
#   patient_id  visit_date   age gender blood_pressure_mmhg  chol_mg_dl  \
# 0       P001  2021-01-03  34.0      M              120/80       180.0
# 1       P002   2021-1-05  45.0      F              135/90       210.0
# 2       P003  03-01-2021  29.0      M              115/75       190.0
# 3       P004  2021-01-04  52.0      F              140/95       220.0
# 4       P005  2021-01-06  33.0      M              118/78       185.0
# 5       P006  2021-01-06  33.0      M              118/78       185.0
# 6       P007  2021-01-07   NaN      M              125/82       200.0
# 7       P008  2021-01-08  46.0      F              130/85       195.0
# 8       P009  2021-01-09  50.0      F              128/84         NaN
# 9       P010  2021-01-10  41.0      M              132/88       210.0
#
#    glucose            notes  systolic  diastolic  glucose_clean  \
# 0       95         baseline       120         80           95.0
# 1      NaN                -       135         90            NaN
# 2       88          recheck       115         75           88.0
# 3  missing      new patient       140         95            NaN
# 4       89           repeat       118         78           89.0
# 5       89           repeat       118         78           89.0
# 6   ninety  typo in glucose       125         82            NaN
# 7      100         baseline       130         85          100.0
# 8       92                -       128         84           92.0
# 9       97        follow-up       132         88           97.0
#
#   visit_date_clean
# 0       2021-01-03
# 1       2021-01-05
# 2              NaT
# 3       2021-01-04
# 4       2021-01-06
# 5       2021-01-06
# 6       2021-01-07
# 7       2021-01-08
# 8       2021-01-09
# 9       2021-01-10

# %% [markdown]
# Convert type in systolic and diastolic pressure columns (pd.to_numeric)

# %% [markdown]
# Add the extended patient list and the patients info.

# %%
df_ex=pd.read_csv("patient_list_extended.csv")
df_2merge=pd.read_csv("patients_info.csv")

# %%
df_extend=pd.concat([df,df_ex], ignore_index=True)
df_extend;

# %%
df_complete=pd.merge(df_extend, df_2merge, on="patient_id", how="outer")
df_complete.head()
# Out:
#   patient_id  visit_date   age gender blood_pressure_mmhg  chol_mg_dl  \
# 0       P001  2021-01-03  34.0      M              120/80       180.0
# 1       P002   2021-1-05  45.0      F              135/90       210.0
# 2       P003  03-01-2021  29.0      M              115/75       190.0
# 3       P004  2021-01-04  52.0      F              140/95       220.0
# 4       P005  2021-01-06  33.0      M              118/78       185.0
#
#    glucose        notes  systolic  diastolic  glucose_clean visit_date_clean  \
# 0       95     baseline       120         80           95.0       2021-01-03
# 1      NaN            -       135         90            NaN       2021-01-05
# 2       88      recheck       115         75           88.0              NaT
# 3  missing  new patient       140         95            NaN       2021-01-04
# 4       89       repeat       118         78           89.0       2021-01-06
#
#     bmi  smoker
# 0  24.5  No
# 1  27.2     Yes
# 2  25.0      No
# 3  31.0     Yes
# 4  26.4      No

# %%
df_complete2=df_extend.join(df_2merge, on="patient_id", how="outer")
df_complete2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df_complete2=df_extend.join(df_2merge, on="patient_id", how="outer")
#       2 df_complete2
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:10757, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10747     if how == "cross":
#   10748         return merge(
#   10749             self,
#   10750             other,
#    (...)
#   10755             validate=validate,
#   10756         )
# > 10757     return merge(
#   10758         self,
#   10759         other,
#   10760         left_on=on,
#   10761         how=how,
#   10762         left_index=on is None,
#   10763         right_index=True,
#   10764         suffixes=(lsuffix, rsuffix),
#   10765         sort=sort,
#   10766         validate=validate,
#   10767     )
#   10768 else:
#   10769     if on is not None:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)
#     167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
#     179         sort=sort,
#     180         suffixes=suffixes,
#     181         indicator=indicator,
#     182         validate=validate,
#     183     )
#     184     return op.get_result(copy=copy)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:807, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     803 self._validate_tolerance(self.left_join_keys)
#     805 # validate the merge keys dtypes. We may need to coerce
#     806 # to avoid incompatible dtypes
# --> 807 self._maybe_coerce_merge_keys()
#     809 # If argument passed to validate,
#     810 # check if columns specified as unique
#     811 # are in fact unique.
#     812 if validate is not None:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:1508, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1502     # unless we are merging non-string-like with string-like
#    1503     elif (
#    1504         inferred_left in string_types and inferred_right not in string_types
#    1505     ) or (
#    1506         inferred_right in string_types and inferred_left not in string_types
#    1507     ):
# -> 1508         raise ValueError(msg)
#    1510 # datetimelikes must match exactly
#    1511 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on object and int64 columns for key 'patient_id'. If you wish to proceed you should use pd.concat

# %%
print(df.shape)
print(df_ex.shape)
print(df_extend.shape)
print(df_2merge.shape)
print(df_complete.shape)
# Out:
# (10, 12)
# (42, 10)
# (52, 12)
# (38, 3)
# (56, 14)

# %%
df_complete.to_csv("patients_list_complete.csv", index=False)

# %%
df_complete.isna().sum()
# Out:
# patient_id              0
# visit_date              0
# age                     9
# gender                  0
# blood_pressure_mmhg     0
# chol_mg_dl              7
# glucose                13
# notes                  21
# systolic                0
# diastolic               0
# glucose_clean          49
# visit_date_clean       47
# bmi                    18
# smoker                 24
# dtype: int64

# %%
df_complete["is_age_missing"]=df.age.isna()
df_complete;

# %%
df_dropna_smokers=df_complete.dropna(subset="smoker")
df_dropna_smokers;

df_dropna_chol=df_complete.dropna(subset="chol_mg_dl")
df_dropna_chol
# Out:
#    patient_id  visit_date    age gender blood_pressure_mmhg  chol_mg_dl  \
# 0        P001  2021-01-03   34.0      M              120/80       180.0
# 1        P002   2021-1-05   45.0      F              135/90       210.0
# 2        P003  03-01-2021   29.0      M              115/75       190.0
# 3        P004  2021-01-04   52.0      F              140/95       220.0
# 4        P005  2021-01-06   33.0      M              118/78       185.0
# 5        P006  2021-01-06   33.0      M              118/78       185.0
# 6        P007  2021-01-07    NaN      M              125/82       200.0
# 7        P008  2021-01-08   46.0      F              130/85       195.0
# 9        P010  2021-01-10   41.0      M              132/88       210.0
# 10       P011  2021-01-03   33.0      M              110/81       177.0
# 12       P013   2021/1/05   69.0      M              125/75       190.0
# 13       P014  2021.01.04   42.0      F              130/91       228.0
# 14       P015  2021-01-06   43.0      M              118/79       134.0
# 15       P016  2021-01-06   63.0      M              133/78       188.0
# 16       P017  2021/01/07    NaN      M              122/82       210.0
# 17       P018  2021-01-08    NaN      F              134/86       192.0
# 18       P018  2021-01-08    NaN      F              134/86       192.0
# 20       P020  2021-01-10   41.0      M              112/78       210.0
# 23       P022  2021/01/07   66.0      F              132/90       211.0
# 24       P022  2021/01/07   66.0      F              132/90       211.0
# 25       P023  2021/01/07   29.0      M              131/75       149.0
# 26       P023  2021/01/07   29.0      M              131/75       149.0
# 27       P024  2021.01.04   51.0      F              130/95       228.0
# 28       P024  2021.01.04   51.0      F              130/95       228.0
# 29       P025  2021-01-06   31.0      D              128/83       122.0
# 30       P026  2021-01-06   33.0      M              138/88       186.0
# 32       P028  2021-01-08   47.0      F              140/85       195.0
# 33       P029  2021-01-06   58.0      F              145/89       126.0
# 34       P030  2021-01-10   48.0      M              137/88       240.0
# 35       P031  2021-01-06   12.0      M              122/80       110.0
# 36       P032   2021/1/05   45.0      F              115/90       213.0
# 37       P033  2021-01-06    NaN      M              123/86       194.0
# 38       P034  2021.01.04   74.0      F              141/95       210.0
# 39       P035  2021-01-08   37.0      M              123/85       175.0
# 40       P036  2021-01-06    NaN      M              118/83       165.0
# 41       P037  2021/01/07    NaN      M              127/84       140.0
# 42       P038  2021-01-08   26.0      D              131/85       150.0
# 43       P039  2021-01-09   57.0      F              133/87       134.0
# 44       P040  2021-01-10   41.0      M              132/82       170.0
# 45       P041  2021-01-03   38.0      M              123/82       150.0
# 46       P042   2021/1/05   43.0      F              135/91       213.0
# 47       P043  03-01-2021   69.0      M              155/95       170.0
# 48       P044  2021.01.08   42.0      F              130/78       210.0
# 49       P044  2021.01.08   42.0      F              130/78       210.0
# 50       P045  2021-01-06   13.0      M              112/75       185.0
# 51       P046  2021-01-06  133.0      D              113/78       135.0
# 52       P047  2021/01/07    NaN      M              115/82       150.0
# 53       P048  2021-01-08   48.0      F              131/85       145.0
# 55       P050  2021-01-13   42.0      M              133/87       190.0
#
#     glucose            notes  systolic  diastolic  glucose_clean  \
# 0        95         baseline       120         80           95.0
# 1       NaN                -       135         90            NaN
# 2        88          recheck       115         75           88.0
# 3   missing      new patient       140         95            NaN
# 4        89           repeat       118         78           89.0
# 5        89           repeat       118         78           89.0
# 6    ninety  typo in glucose       125         82            NaN
# 7       100         baseline       130         85          100.0
# 9        97        follow-up       132         88           97.0
# 10     85.0         baseline       110         81            NaN
# 12     82.0              NaN       125         75            NaN
# 13    125.0      new patient       130         91            NaN
# 14    111.0              NaN       118         79            NaN
# 15     99.0           repeat       133         78            NaN
# 16     76.0      new patient       122         82            NaN
# 17    130.0              NaN       134         86            NaN
# 18    130.0              NaN       134         86            NaN
# 20     94.0        follow-up       112         78            NaN
# 23      NaN                -       132         90            NaN
# 24      NaN                -       132         90            NaN
# 25      NaN              NaN       131         75            NaN
# 26      NaN              NaN       131         75            NaN
# 27     76.0              NaN       130         95            NaN
# 28     76.0              NaN       130         95            NaN
# 29    128.0              NaN       128         83            NaN
# 30     84.0              NaN       138         88            NaN
# 32    170.0         baseline       140         85            NaN
# 33     72.0                -       145         89            NaN
# 34      NaN        follow-up       137         88            NaN
# 35      NaN              NaN       122         80            NaN
# 36      NaN                -       115         90            NaN
# 37    118.0          recheck       123         86            NaN
# 38    100.0          recheck       141         95            NaN
# 39     79.0              NaN       123         85            NaN
# 40     85.0          recheck       118         83            NaN
# 41   1200.0      new patient       127         84            NaN
# 42    100.0         baseline       131         85            NaN
# 43      NaN                -       133         87            NaN
# 44     92.0        follow-up       132         82            NaN
# 45     84.0              NaN       123         82            NaN
# 46      NaN                -       135         91            NaN
# 47     88.0              NaN       155         95            NaN
# 48      NaN              NaN       130         78            NaN
# 49      NaN              NaN       130         78            NaN
# 50     75.0      new patient       112         75            NaN
# 51     89.0           repeat       113         78            NaN
# 52    111.0              NaN       115         82            NaN
# 53    140.0              NaN       131         85            NaN
# 55     88.0        follow-up       133         87            NaN
#
#    visit_date_clean   bmi  smoker is_age_missing
# 0        2021-01-03  24.5  No              False
# 1        2021-01-05  27.2     Yes          False
# 2               NaT  25.0      No          False
# 3        2021-01-04  31.0     Yes          False
# 4        2021-01-06  26.4      No          False
# 5        2021-01-06  22.5  No              False
# 6        2021-01-07  24.2     Yes           True
# 7        2021-01-08  23.0      No          False
# 9        2021-01-10  22.4      No          False
# 10              NaT  22.5  No                NaN
# 12              NaT  24.0      No            NaN
# 13              NaT  21.0     NaN            NaN
# 14              NaT  25.4      No            NaN
# 15              NaT  22.5  No                NaN
# 16              NaT  21.2     Yes            NaN
# 17              NaT   NaN     NaN            NaN
# 18              NaT   NaN     NaN            NaN
# 20              NaT   NaN     NaN            NaN
# 23              NaT  25.7      No            NaN
# 24              NaT  25.4     NaN            NaN
# 25              NaT  22.2  No                NaN
# 26              NaT  25.2  No                NaN
# 27              NaT  22.4     Yes            NaN
# 28              NaT  21.4     Yes            NaN
# 29              NaT  22.7  No                NaN
# 30              NaT  24.1     NaN            NaN
# 32              NaT  21.0     Yes            NaN
# 33              NaT  27.0      No            NaN
# 34              NaT  22.4      No            NaN
# 35              NaT  22.5                    NaN
# 36              NaT  26.2     Yes            NaN
# 37              NaT   NaN     NaN            NaN
# 38              NaT   NaN     NaN            NaN
# 39              NaT  22.7  No                NaN
# 40              NaT   NaN     NaN            NaN
# 41              NaT  23.1      No            NaN
# 42              NaT  22.0     Yes            NaN
# 43              NaT  28.0     NaN            NaN
# 44              NaT  31.4      No            NaN
# 45              NaT   NaN     NaN            NaN
# 46              NaT   NaN     NaN            NaN
# 47              NaT   NaN     NaN            NaN
# 48              NaT   NaN     NaN            NaN
# 49              NaT   NaN     NaN            NaN
# 50              NaT   NaN     NaN            NaN
# 51              NaT   NaN     NaN            NaN
# 52              NaT   NaN     NaN            NaN
# 53              NaT   NaN     NaN            NaN
# 55              NaT   NaN     NaN            NaN

# %%
import seaborn as sn

# %%
sn.histplot(df_dropna_chol["chol_mg_dl"])
# Out:
# <Axes: xlabel='chol_mg_dl', ylabel='Count'>
